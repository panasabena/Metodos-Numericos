# %% [markdown]
# ## Importamos librerías

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# %%
## Quiero repasar algunos conceptos de derivada

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Calcular los valores de f(x, y)
f_values = f(x, y)

# Crear la figura y el subplot 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar la función f(x, y)
# para agregarle contorno a la gráfica hay que cambiar el edge color a 'black'
ax.plot_surface(x, y, f_values, cmap='viridis', edgecolor='none', alpha=0.8)

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Función 3X^2 + 5xy - 7y^2 + 1')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# #### Ahora agregamos al gráfico la función derivada con respecto a x

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir la derivada parcial df/dx
def df_dx(x, y):
    return 6 * x + 5 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Calcular los valores de f(x, y) y df/dx
f_values = f(x, y)
df_dx_values = df_dx(x, y)

# Crear la figura y el subplot 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar la función f(x, y) sin contornos
ax.plot_surface(x, y, f_values, cmap='viridis', edgecolor='none')

# Graficar la derivada df/dx como líneas en el plano xy
ax.plot_wireframe(x, y, df_dx_values, colors='grey', linewidths=1)

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Función sin derivar y derivada en x')

# Mostrar el gráfico
plt.show()

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir la derivada parcial df/dx
def df_dx(x, y):
    return 6 * x + 5 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Calcular los valores de f(x, y) y df/dx
f_values = f(x, y)
df_dx_values = df_dx(x, y)

# Crear la figura y el subplot 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar la función f(x, y) sin contornos
ax.plot_surface(x, y, f_values, cmap='viridis', edgecolor='none')

# Graficar la derivada df/dx como líneas en el plano xy
ax.plot_wireframe(x, y, df_dx_values, colors='red', linewidths=1)

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Vista desde el plano z')

# Rotar el gráfico para ver desde el plano Z
ax.view_init(elev=90, azim=0)  # Ángulo de elevación: 90, Ángulo de azimut: 0
plt.show()

plt.show()

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir la derivada parcial df/dx
def df_dx(x, y):
    return 6 * x + 5 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Calcular los valores de f(x, y) y df/dx
f_values = f(x, y)
df_dx_values = df_dx(x, y)

# Crear la figura y el subplot 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar la función f(x, y) sin contornos
ax.plot_surface(x, y, f_values, cmap='viridis', edgecolor='none')

# Graficar la derivada df/dx como líneas en el plano xy
ax.plot_wireframe(x, y, df_dx_values, colors='red', linewidths=1)

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Vista desde el plano y')

# Rotar el gráfico para ver desde el plano Y
ax.view_init(elev=0, azim=0)  # Ángulo de elevación: 0, Ángulo de azimut: 0
plt.show()

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir la derivada parcial df/dx
def df_dx(x, y):
    return 6 * x + 5 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Calcular los valores de f(x, y) y df/dx
f_values = f(x, y)
df_dx_values = df_dx(x, y)

# Crear la figura y el subplot 3D
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Graficar la función f(x, y) sin contornos
ax.plot_surface(x, y, f_values, cmap='viridis', edgecolor='none')

# Graficar la derivada df/dx como líneas en el plano xy
ax.plot_wireframe(x, y, df_dx_values, colors='red', linewidths=1)

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Vista desde el plano x')

# Rotar el gráfico para ver desde el plano Y
ax.view_init(elev=0, azim=90)  # Ángulo de elevación: 0, Ángulo de azimut: 0
plt.show()

# %% [markdown]
# #### Ahora agregamos la funcion derivada parcial en y

# %%
# Definir las funciones f(x, y), df/dx y df/dy
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

def df_dx(x, y):
    return 6 * x + 5 * y

def df_dy(x, y):
    return 5 * x - 14 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

# Calcular los valores de f(x, y), df/dx y df/dy
f_values = f(x, y)
df_dx_values = df_dx(x, y)
df_dy_values = df_dy(x, y)

# Graficar las funciones f(x, y), df/dx y df/dy
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, f_values, cmap='viridis', edgecolor='none', alpha=0.3)
ax.plot_surface(x, y, df_dx_values, cmap='plasma', edgecolor='none', alpha=0.8)
ax.plot_surface(x, y, df_dy_values, cmap='magma', edgecolor='none', alpha=0.8)

# Graficar los contornos de las intersecciones
contour_levels = [0]
ax.contour(x, y, f_values, contour_levels, colors='red', linestyles='dashed')
ax.contour(x, y, df_dx_values, contour_levels, colors='blue', linestyles='dashed')
ax.contour(x, y, df_dy_values, contour_levels, colors='green', linestyles='dashed')

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Funciones y contornos de intersecciones')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Este código calculará los valores de f(x, y) y df/dx en una malla de coordenadas (x, y) y luego trazará los contornos de intersección entre f y df/dx en color rojo y azul respectivament

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir la derivada parcial df/dx
def df_dx(x, y):
    return 6 * x + 5 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

# Crear una malla de coordenadas (x, y)
X, Y = np.meshgrid(x, y)

# Calcular los valores de f(x, y) y df/dx en la malla
Z_f = f(X, Y)
Z_df_dx = df_dx(X, Y)

# Graficar la intersección de f y df/dx
plt.contour(X, Y, Z_f, levels=[0], colors='red', linestyles='dashed')
plt.contour(X, Y, Z_df_dx, levels=[0], colors='blue', linestyles='dashed')

# Personalizar el gráfico
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Intersección de f y df/dx')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Este código creará un gráfico 3D con la superficie de la función f(x, y) y los contornos de intersección entre f y df/dx trazados en color rojo y azul respectivamente.

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir la derivada parcial df/dx
def df_dx(x, y):
    return 6 * x + 5 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

# Crear una malla de coordenadas (x, y)
X, Y = np.meshgrid(x, y)

# Calcular los valores de f(x, y) y df/dx en la malla
Z_f = f(X, Y)
Z_df_dx = df_dx(X, Y)

# Crear la figura y los ejes 3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Graficar la superficie de f(x, y)
ax.plot_surface(X, Y, Z_f, cmap='viridis', edgecolor='none', alpha=0.8)

# Graficar los contornos de la intersección de f y df/dx
ax.contour(X, Y, Z_f, levels=[0], colors='red', linestyles='dashed')
ax.contour(X, Y, Z_df_dx, levels=[0], colors='blue', linestyles='dashed')

# Personalizar el gráfico
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Intersección de f y df/dx en 3D')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Este código agregará una nueva línea que grafica la intersección entre f y df/dy en color verde. Cada línea de contorno representa la intersección de la función f con una de las derivadas parciales df/dx y df/dy en el plano XY.

# %%
# Definir la función f(x, y)
def f(x, y):
    return 3 * x**2 + 5 * x * y - 7 * y**2 + 1

# Definir las derivadas parciales df/dx y df/dy
def df_dx(x, y):
    return 6 * x + 5 * y

def df_dy(x, y):
    return 5 * x - 14 * y

# Definir los rangos de valores para x y y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

# Crear una malla de coordenadas (x, y)
X, Y = np.meshgrid(x, y)

# Calcular los valores de f(x, y), df/dx y df/dy en la malla
Z_f = f(X, Y)
Z_df_dx = df_dx(X, Y)
Z_df_dy = df_dy(X, Y)

# Graficar la función f(x, y)
plt.contour(X, Y, Z_f, levels=[0], colors='red', linestyles='dashed')

# Graficar la intersección de f y df/dx
plt.contour(X, Y, Z_df_dx, levels=[0], colors='blue', linestyles='dashed')

# Graficar la intersección de f y df/dy
plt.contour(X, Y, Z_df_dy, levels=[0], colors='green', linestyles='dashed')

# Personalizar el gráfico
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Intersección de f, df/dx y df/dy')

# Mostrar el gráfico
plt.show()
